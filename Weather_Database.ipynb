# %%
# Import the dependencies
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import timeit

# # Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Import Dependencies

from datetime import datetime

# %%
# Gettin 2000 randomly generated latitudes and longitudes
lats = np.random.uniform(-90.000, 90.000, size =2000)
longs = np.random.uniform(-90.000, 90.000, size =2000)
lat_long = zip(lats, longs)

coordinates = list(lat_long)

# %%
#Starting URL for Weather Map API call

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a list for holding the ciites
cities = []

#Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    #If the city is unique, the we add it to the cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 759

# %%
# Create an empty list to hold the weather data
city_data = []

# print the beginning of the logging

print("Beginning Data Retrieval      ")
print("------------------------------")

#Create counters

record_count = 1
set_count = 1# loop through all the cities

for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes:
    if(i% 50 == 0 and i>=50):
        set_count +=1
        record_count +=1
    
    #create endpoint URL with each city
    city_url = url +"&q=" + city.replace(" ","+")
    
    #Log the url, record and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count}| {city} ")
    
    # Add 1 to the record count
    record_count +=1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description =city_weather["weather"][0]["description"]
                
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description":city_current_description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1| hualmay
# Processing Record 2 of Set 1| ushuaia
# Processing Record 3 of Set 1| matara
# Processing Record 4 of Set 1| port blair
# Processing Record 5 of Set 1| rudsar
# Processing Record 6 of Set 1| praia da vitoria
# Processing Record 7 of Set 1| bayji
# Processing Record 8 of Set 1| saint-philippe
# Processing Record 9 of Set 1| bolshoy tsaryn
# City not found. Skipping...
# Processing Record 10 of Set 1| port alfred
# Processing Record 11 of Set 1| kesova gora
# Processing Record 12 of Set 1| ibotirama
# Processing Record 13 of Set 1| chuy
# Processing Record 14 of Set 1| bodden town
# Processing Record 15 of Set 1| kegayli
# City not found. Skipping...
# Processing Record 16 of Set 1| bathsheba
# Processing Record 17 of Set 1| georgetown
# Processing Record 18 of Set 1| hithadhoo
# Processing Record 19 of Set 1| attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 1| belmonte
# Processing Record 21 of Set 1| cidreira
# Processing Record 22 of Set 1| vila franca do campo
# Processing Record 23 of Set 1| kuybyshevskiy zaton
# Processing Record 24 of Set 1| lebu
# Processing Record 25 of Set 1| meulaboh
# Processing Record 26 of Set 1| port elizabeth
# Processing Record 27 of Set 1| bredasdorp
# Processing Record 28 of Set 1| vreed en hoop
# City not found. Skipping...
# Processing Record 29 of Set 1| toliary
# City not found. Skipping...
# Processing Record 30 of Set 1| grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 1| mahebourg
# Processing Record 32 of Set 1| saint anthony
# Processing Record 33 of Set 1| adrar
# Processing Record 34 of Set 1| busselton
# Processing Record 35 of Set 1| nodeland
# Processing Record 36 of Set 1| sanary-sur-mer
# Processing Record 37 of Set 1| balkanabat
# Processing Record 38 of Set 1| taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 1| nador
# Processing Record 40 of Set 1| oistins
# Processing Record 41 of Set 1| menongue
# Processing Record 42 of Set 1| east london
# Processing Record 43 of Set 1| hermanus
# Processing Record 44 of Set 1| sakakah
# Processing Record 45 of Set 1| punta arenas
# Processing Record 46 of Set 1| troitsko-pechorsk
# Processing Record 47 of Set 1| sarankhola
# Processing Record 48 of Set 1| sao geraldo do araguaia
# Processing Record 49 of Set 1| stornoway
# Processing Record 50 of Set 1| jamestown
# Processing Record 52 of Set 2| quatre cocos
# Processing Record 53 of Set 2| mosalsk
# Processing Record 54 of Set 2| le port
# Processing Record 55 of Set 2| hofn
# Processing Record 56 of Set 2| castro
# Processing Record 57 of Set 2| umzimvubu
# City not found. Skipping...
# Processing Record 58 of Set 2| souillac
# Processing Record 59 of Set 2| illoqqortoormiut
# City not found. Skipping...
# Processing Record 60 of Set 2| caravelas
# Processing Record 61 of Set 2| ghansor
# Processing Record 62 of Set 2| ilulissat
# Processing Record 63 of Set 2| hopelchen
# Processing Record 64 of Set 2| dingle
# Processing Record 65 of Set 2| onega
# Processing Record 66 of Set 2| road town
# Processing Record 67 of Set 2| cape town
# Processing Record 68 of Set 2| arraial do cabo
# Processing Record 69 of Set 2| saldanha
# Processing Record 70 of Set 2| mar del plata
# Processing Record 71 of Set 2| chimore
# Processing Record 72 of Set 2| tsihombe
# City not found. Skipping...
# Processing Record 73 of Set 2| kulhudhuffushi
# Processing Record 74 of Set 2| golden rock
# City not found. Skipping...
# Processing Record 75 of Set 2| san pedro
# Processing Record 76 of Set 2| taoudenni
# Processing Record 77 of Set 2| kirundo
# Processing Record 78 of Set 2| marquette
# Processing Record 79 of Set 2| puerto carreno
# Processing Record 80 of Set 2| qasigiannguit
# Processing Record 81 of Set 2| san clemente
# Processing Record 82 of Set 2| lodja
# Processing Record 83 of Set 2| nynashamn
# Processing Record 84 of Set 2| bambous virieux
# Processing Record 85 of Set 2| ponta do sol
# Processing Record 86 of Set 2| viamao
# Processing Record 87 of Set 2| tumannyy
# City not found. Skipping...
# Processing Record 88 of Set 2| upernavik
# Processing Record 89 of Set 2| bayevo
# Processing Record 90 of Set 2| aktau
# Processing Record 91 of Set 2| carballo
# Processing Record 92 of Set 2| lingsugur
# Processing Record 93 of Set 2| ribeira grande
# Processing Record 94 of Set 2| skibbereen
# Processing Record 95 of Set 2| mariental
# Processing Record 96 of Set 2| havoysund
# Processing Record 97 of Set 2| babocsa
# Processing Record 98 of Set 2| sept-iles
# Processing Record 99 of Set 2| malakal
# Processing Record 100 of Set 2| barabinsk
# Processing Record 101 of Set 2| nelson
# Processing Record 103 of Set 3| newcastle
# Processing Record 104 of Set 3| trzcianka
# Processing Record 105 of Set 3| purranque
# Processing Record 106 of Set 3| angoche
# Processing Record 107 of Set 3| san luis
# Processing Record 108 of Set 3| nata
# Processing Record 109 of Set 3| polyarnyy
# Processing Record 110 of Set 3| skjervoy
# Processing Record 111 of Set 3| pamplona
# Processing Record 112 of Set 3| barentsburg
# City not found. Skipping...
# Processing Record 113 of Set 3| mahoba
# Processing Record 114 of Set 3| karaul
# City not found. Skipping...
# Processing Record 115 of Set 3| torbay
# Processing Record 116 of Set 3| narsaq
# Processing Record 117 of Set 3| coquimbo
# Processing Record 118 of Set 3| isiro
# Processing Record 119 of Set 3| tigri
# City not found. Skipping...
# Processing Record 120 of Set 3| oriximina
# Processing Record 121 of Set 3| nola
# Processing Record 122 of Set 3| gamba
# Processing Record 123 of Set 3| belushya guba
# City not found. Skipping...
# Processing Record 124 of Set 3| tobol
# Processing Record 125 of Set 3| carnarvon
# Processing Record 126 of Set 3| plettenberg bay
# Processing Record 127 of Set 3| camacha
# Processing Record 128 of Set 3| axim
# Processing Record 129 of Set 3| clyde river
# Processing Record 130 of Set 3| qaanaaq
# Processing Record 131 of Set 3| marsh harbour
# Processing Record 132 of Set 3| senno
# Processing Record 133 of Set 3| dikson
# Processing Record 134 of Set 3| tumaco
# Processing Record 135 of Set 3| robertsport
# Processing Record 136 of Set 3| touros
# Processing Record 137 of Set 3| gumdag
# Processing Record 138 of Set 3| rio grande
# Processing Record 139 of Set 3| thinadhoo
# Processing Record 140 of Set 3| asfi
# Processing Record 141 of Set 3| kamoke
# Processing Record 142 of Set 3| havelock
# Processing Record 143 of Set 3| hambantota
# Processing Record 144 of Set 3| vardo
# Processing Record 145 of Set 3| victoria
# Processing Record 146 of Set 3| zhezkazgan
# Processing Record 147 of Set 3| shagamu
# Processing Record 148 of Set 3| kyshtovka
# Processing Record 149 of Set 3| grand gaube
# Processing Record 150 of Set 3| sao filipe
# Processing Record 151 of Set 3| mari-turek
# Processing Record 152 of Set 3| ternovka
# Processing Record 154 of Set 4| arosa
# Processing Record 155 of Set 4| formoso do araguaia
# City not found. Skipping...
# Processing Record 156 of Set 4| hamilton
# Processing Record 157 of Set 4| buraydah
# Processing Record 158 of Set 4| jensen beach
# Processing Record 159 of Set 4| fonte boa
# Processing Record 160 of Set 4| sokoni
# Processing Record 161 of Set 4| aqtobe
# Processing Record 162 of Set 4| yar-sale
# Processing Record 163 of Set 4| shelbyville
# Processing Record 164 of Set 4| balezino
# Processing Record 165 of Set 4| luderitz
# Processing Record 166 of Set 4| falun
# Processing Record 167 of Set 4| farafangana
# Processing Record 168 of Set 4| filadelfia
# Processing Record 169 of Set 4| ostrovnoy
# Processing Record 170 of Set 4| isabela
# Processing Record 171 of Set 4| warqla
# City not found. Skipping...
# Processing Record 172 of Set 4| port-cartier
# Processing Record 173 of Set 4| teseney
# Processing Record 174 of Set 4| iqaluit
# Processing Record 175 of Set 4| chistoye
# Processing Record 176 of Set 4| bolshoye sorokino
# City not found. Skipping...
# Processing Record 177 of Set 4| lagoa
# Processing Record 178 of Set 4| palma soriano
# Processing Record 179 of Set 4| kralendijk
# Processing Record 180 of Set 4| abu zabad
# Processing Record 181 of Set 4| mikhaylovskoye
# Processing Record 182 of Set 4| summerville
# Processing Record 183 of Set 4| amderma
# City not found. Skipping...
# Processing Record 184 of Set 4| longyearbyen
# Processing Record 185 of Set 4| antalaha
# Processing Record 186 of Set 4| nicoya
# Processing Record 187 of Set 4| amapa
# Processing Record 188 of Set 4| margate
# Processing Record 189 of Set 4| namibe
# Processing Record 190 of Set 4| miranorte
# City not found. Skipping...
# Processing Record 191 of Set 4| comodoro rivadavia
# Processing Record 192 of Set 4| karonga
# Processing Record 193 of Set 4| temiscaming
# Processing Record 194 of Set 4| aripuana
# Processing Record 195 of Set 4| kamenka
# Processing Record 196 of Set 4| kuri
# Processing Record 197 of Set 4| tigzirt
# Processing Record 198 of Set 4| mayumba
# Processing Record 199 of Set 4| tasiilaq
# Processing Record 200 of Set 4| atar
# Processing Record 201 of Set 4| muros
# Processing Record 202 of Set 4| beira
# Processing Record 203 of Set 4| sarkand
# Processing Record 205 of Set 5| takoradi
# Processing Record 206 of Set 5| fara in sabina
# Processing Record 207 of Set 5| ateli
# Processing Record 208 of Set 5| pisco
# Processing Record 209 of Set 5| sinnamary
# Processing Record 210 of Set 5| burica
# City not found. Skipping...
# Processing Record 211 of Set 5| titlagarh
# Processing Record 212 of Set 5| necochea
# Processing Record 213 of Set 5| conde
# Processing Record 214 of Set 5| nuuk
# Processing Record 215 of Set 5| birjand
# Processing Record 216 of Set 5| cap malheureux
# Processing Record 217 of Set 5| itaituba
# Processing Record 218 of Set 5| tazovskiy
# Processing Record 219 of Set 5| jardim
# Processing Record 220 of Set 5| bud
# Processing Record 221 of Set 5| phalombe
# Processing Record 222 of Set 5| acurenam
# Processing Record 223 of Set 5| olyka
# Processing Record 224 of Set 5| ancud
# Processing Record 225 of Set 5| savelugu
# Processing Record 226 of Set 5| manitouwadge
# Processing Record 227 of Set 5| presidencia roque saenz pena
# Processing Record 228 of Set 5| morant bay
# Processing Record 229 of Set 5| bhor
# Processing Record 230 of Set 5| aswan
# Processing Record 231 of Set 5| verkhnyaya inta
# Processing Record 232 of Set 5| safaga
# Processing Record 233 of Set 5| rengo
# Processing Record 234 of Set 5| rosetta
# Processing Record 235 of Set 5| zyryanovsk
# Processing Record 236 of Set 5| iralaya
# Processing Record 237 of Set 5| floresta
# Processing Record 238 of Set 5| belyy yar
# Processing Record 239 of Set 5| coihaique
# Processing Record 240 of Set 5| shadegan
# Processing Record 241 of Set 5| chapais
# Processing Record 242 of Set 5| binga
# Processing Record 243 of Set 5| puerto colombia
# Processing Record 244 of Set 5| betioky
# Processing Record 245 of Set 5| linden
# Processing Record 246 of Set 5| riyadh
# Processing Record 247 of Set 5| dwarka
# Processing Record 248 of Set 5| beloha
# Processing Record 249 of Set 5| brae
# Processing Record 250 of Set 5| tabou
# Processing Record 251 of Set 5| morristown
# Processing Record 252 of Set 5| nizhyn
# Processing Record 253 of Set 5| colesberg
# Processing Record 254 of Set 5| laguna
# Processing Record 256 of Set 6| buhovo
# Processing Record 257 of Set 6| baryshivka
# Processing Record 258 of Set 6| floro
# Processing Record 259 of Set 6| taywarah
# Processing Record 260 of Set 6| pangnirtung
# Processing Record 261 of Set 6| trairi
# Processing Record 262 of Set 6| gelgaudiskis
# Processing Record 263 of Set 6| berlevag
# Processing Record 264 of Set 6| tromso
# Processing Record 265 of Set 6| puri
# Processing Record 266 of Set 6| amvrosiyivka
# Processing Record 267 of Set 6| dzhusaly
# City not found. Skipping...
# Processing Record 268 of Set 6| kutum
# Processing Record 269 of Set 6| bitburg
# Processing Record 270 of Set 6| klaksvik
# Processing Record 271 of Set 6| mingrelskaya
# Processing Record 272 of Set 6| korla
# Processing Record 273 of Set 6| chimbote
# Processing Record 274 of Set 6| boa vista
# Processing Record 275 of Set 6| kokemaki
# Processing Record 276 of Set 6| tsogni
# Processing Record 277 of Set 6| bilma
# Processing Record 278 of Set 6| jawhar
# Processing Record 279 of Set 6| taby
# Processing Record 280 of Set 6| marfino
# Processing Record 281 of Set 6| kotido
# Processing Record 282 of Set 6| vannes
# Processing Record 283 of Set 6| sechura
# Processing Record 284 of Set 6| tsentralnyy
# City not found. Skipping...
# Processing Record 285 of Set 6| ushtobe
# Processing Record 286 of Set 6| trincomalee
# Processing Record 287 of Set 6| henties bay
# Processing Record 288 of Set 6| luwero
# Processing Record 289 of Set 6| iraucuba
# Processing Record 290 of Set 6| iranshahr
# Processing Record 291 of Set 6| bolshoye selo
# Processing Record 292 of Set 6| ugoofaaru
# Processing Record 293 of Set 6| liverpool
# Processing Record 294 of Set 6| codrington
# Processing Record 295 of Set 6| tanout
# Processing Record 296 of Set 6| jazzin
# City not found. Skipping...
# Processing Record 297 of Set 6| husum
# Processing Record 298 of Set 6| sabha
# Processing Record 299 of Set 6| cabedelo
# Processing Record 300 of Set 6| surami
# Processing Record 301 of Set 6| dalbandin
# Processing Record 302 of Set 6| karwar
# Processing Record 303 of Set 6| madimba
# Processing Record 304 of Set 6| gemena
# Processing Record 305 of Set 6| luanda
# Processing Record 307 of Set 7| estelle
# Processing Record 308 of Set 7| pinerolo
# Processing Record 309 of Set 7| mormugao
# Processing Record 310 of Set 7| dumbravita
# Processing Record 311 of Set 7| zagreb
# Processing Record 312 of Set 7| jalu
# Processing Record 313 of Set 7| micheweni
# Processing Record 314 of Set 7| xapuri
# Processing Record 315 of Set 7| ilheus
# Processing Record 316 of Set 7| palmeirais
# Processing Record 317 of Set 7| grao mogol
# Processing Record 318 of Set 7| santa cruz cabralia
# Processing Record 319 of Set 7| port shepstone
# Processing Record 320 of Set 7| manjacaze
# Processing Record 321 of Set 7| bocaiuva
# Processing Record 322 of Set 7| jumla
# Processing Record 323 of Set 7| mastic beach
# Processing Record 324 of Set 7| urucara
# Processing Record 325 of Set 7| terrace bay
# Processing Record 326 of Set 7| lixourion
# Processing Record 327 of Set 7| basoko
# Processing Record 328 of Set 7| urengoy
# Processing Record 329 of Set 7| dombarovskiy
# Processing Record 330 of Set 7| weligama
# Processing Record 331 of Set 7| maldonado
# Processing Record 332 of Set 7| sistranda
# Processing Record 333 of Set 7| ajdabiya
# Processing Record 334 of Set 7| djibo
# Processing Record 335 of Set 7| kizilskoye
# Processing Record 336 of Set 7| teguldet
# Processing Record 337 of Set 7| saint-joseph
# Processing Record 338 of Set 7| golkoy
# Processing Record 339 of Set 7| saint-augustin
# Processing Record 340 of Set 7| kargasok
# Processing Record 341 of Set 7| bhag
# Processing Record 342 of Set 7| rio verde de mato grosso
# Processing Record 343 of Set 7| ginda
# Processing Record 344 of Set 7| bonavista
# Processing Record 345 of Set 7| doha
# Processing Record 346 of Set 7| bubaque
# Processing Record 347 of Set 7| taloqan
# Processing Record 348 of Set 7| grindavik
# Processing Record 349 of Set 7| luena
# Processing Record 350 of Set 7| geraldton
# Processing Record 351 of Set 7| san andres
# Processing Record 352 of Set 7| aubiere
# Processing Record 353 of Set 7| taltal
# Processing Record 354 of Set 7| vila velha
# Processing Record 355 of Set 7| bosaso
# Processing Record 356 of Set 7| westport
# Processing Record 358 of Set 8| khash
# Processing Record 359 of Set 8| corinto
# Processing Record 360 of Set 8| ust-tsilma
# Processing Record 361 of Set 8| mezen
# Processing Record 362 of Set 8| colwyn bay
# Processing Record 363 of Set 8| matagami
# Processing Record 364 of Set 8| lubango
# Processing Record 365 of Set 8| kalundborg
# Processing Record 366 of Set 8| kasaragod
# Processing Record 367 of Set 8| liwale
# Processing Record 368 of Set 8| veraval
# Processing Record 369 of Set 8| ndola
# Processing Record 370 of Set 8| rawson
# Processing Record 371 of Set 8| derzhavinsk
# Processing Record 372 of Set 8| parainen
# Processing Record 373 of Set 8| vuktyl
# Processing Record 374 of Set 8| opuwo
# Processing Record 375 of Set 8| zambezi
# Processing Record 376 of Set 8| saladoblanco
# Processing Record 377 of Set 8| tamale
# Processing Record 378 of Set 8| zhanatas
# City not found. Skipping...
# Processing Record 379 of Set 8| lar gerd
# City not found. Skipping...
# Processing Record 380 of Set 8| rumphi
# Processing Record 381 of Set 8| bouar
# Processing Record 382 of Set 8| mocuba
# Processing Record 383 of Set 8| sieradz
# Processing Record 384 of Set 8| krasnoselkup
# Processing Record 385 of Set 8| forio
# Processing Record 386 of Set 8| luau
# Processing Record 387 of Set 8| araouane
# Processing Record 388 of Set 8| miguel calmon
# Processing Record 389 of Set 8| ritchie
# Processing Record 390 of Set 8| andenes
# Processing Record 391 of Set 8| san lawrenz
# Processing Record 392 of Set 8| senneterre
# Processing Record 393 of Set 8| raudeberg
# Processing Record 394 of Set 8| yithion
# City not found. Skipping...
# Processing Record 395 of Set 8| tsagan aman
# Processing Record 396 of Set 8| tharad
# Processing Record 397 of Set 8| olafsvik
# Processing Record 398 of Set 8| sao joao da barra
# Processing Record 399 of Set 8| cayenne
# Processing Record 400 of Set 8| poddorye
# Processing Record 401 of Set 8| agadez
# Processing Record 402 of Set 8| visnes
# Processing Record 403 of Set 8| hobyo
# Processing Record 404 of Set 8| marcona
# City not found. Skipping...
# Processing Record 405 of Set 8| molodizhne
# Processing Record 406 of Set 8| nikolayevka
# Processing Record 407 of Set 8| parsabad
# Processing Record 409 of Set 9| plouzane
# Processing Record 410 of Set 9| saint-pierre
# Processing Record 411 of Set 9| tasbuget
# City not found. Skipping...
# Processing Record 412 of Set 9| kruisfontein
# Processing Record 413 of Set 9| marsa matruh
# Processing Record 414 of Set 9| shubarshi
# Processing Record 415 of Set 9| nacala
# Processing Record 416 of Set 9| swellendam
# Processing Record 417 of Set 9| sayat
# Processing Record 418 of Set 9| nouadhibou
# Processing Record 419 of Set 9| cotonou
# Processing Record 420 of Set 9| miram shah
# Processing Record 421 of Set 9| ampanihy
# Processing Record 422 of Set 9| bosansko grahovo
# Processing Record 423 of Set 9| san ramon
# Processing Record 424 of Set 9| den helder
# Processing Record 425 of Set 9| surt
# Processing Record 426 of Set 9| honningsvag
# Processing Record 427 of Set 9| tyumentsevo
# Processing Record 428 of Set 9| conceicao do mato dentro
# Processing Record 429 of Set 9| cururupu
# Processing Record 430 of Set 9| dimbokro
# Processing Record 431 of Set 9| kodino
# Processing Record 432 of Set 9| tres arroyos
# Processing Record 433 of Set 9| vestmannaeyjar
# Processing Record 434 of Set 9| mitsamiouli
# Processing Record 435 of Set 9| la libertad
# Processing Record 436 of Set 9| faya
# Processing Record 437 of Set 9| rafaela
# Processing Record 438 of Set 9| sembe
# Processing Record 439 of Set 9| kishi
# Processing Record 440 of Set 9| igarka
# Processing Record 441 of Set 9| kalmunai
# Processing Record 442 of Set 9| port hawkesbury
# Processing Record 443 of Set 9| semnan
# Processing Record 444 of Set 9| kapoeta
# Processing Record 445 of Set 9| mpulungu
# Processing Record 446 of Set 9| saint george
# Processing Record 447 of Set 9| damietta
# Processing Record 448 of Set 9| antequera
# Processing Record 449 of Set 9| verkh-chebula
# Processing Record 450 of Set 9| hakvik
# City not found. Skipping...
# Processing Record 451 of Set 9| roald
# Processing Record 452 of Set 9| palampur
# Processing Record 453 of Set 9| paamiut
# Processing Record 454 of Set 9| nanortalik
# Processing Record 455 of Set 9| mezhova
# Processing Record 456 of Set 9| srivardhan
# Processing Record 457 of Set 9| mao
# Processing Record 458 of Set 9| umba
# Processing Record 460 of Set 10| los llanos de aridane
# Processing Record 461 of Set 10| ziarat
# Processing Record 462 of Set 10| skoghall
# Processing Record 463 of Set 10| bandiagara
# Processing Record 464 of Set 10| nioro
# Processing Record 465 of Set 10| dinguiraye
# Processing Record 466 of Set 10| najran
# Processing Record 467 of Set 10| lethem
# Processing Record 468 of Set 10| fuerte olimpo
# Processing Record 469 of Set 10| two rivers
# Processing Record 470 of Set 10| mogadishu
# Processing Record 471 of Set 10| husavik
# Processing Record 472 of Set 10| tonj
# Processing Record 473 of Set 10| teguise
# Processing Record 474 of Set 10| gornopravdinsk
# Processing Record 475 of Set 10| rosario
# Processing Record 476 of Set 10| horta
# Processing Record 477 of Set 10| goderich
# Processing Record 478 of Set 10| kirovskiy
# Processing Record 479 of Set 10| lakhnadon
# Processing Record 480 of Set 10| stephenville
# Processing Record 481 of Set 10| khorixas
# Processing Record 482 of Set 10| umm lajj
# Processing Record 483 of Set 10| iquitos
# Processing Record 484 of Set 10| wahran
# City not found. Skipping...
# Processing Record 485 of Set 10| hearst
# Processing Record 486 of Set 10| olinda
# Processing Record 487 of Set 10| halifax
# Processing Record 488 of Set 10| naryan-mar
# Processing Record 489 of Set 10| felidhoo
# City not found. Skipping...
# Processing Record 490 of Set 10| viedma
# Processing Record 491 of Set 10| natal
# Processing Record 492 of Set 10| paramonga
# Processing Record 493 of Set 10| salamanca
# Processing Record 494 of Set 10| togur
# Processing Record 495 of Set 10| walvis bay
# Processing Record 496 of Set 10| pasni
# Processing Record 497 of Set 10| granja
# Processing Record 498 of Set 10| nantucket
# Processing Record 499 of Set 10| kambove
# Processing Record 500 of Set 10| marienburg
# Processing Record 501 of Set 10| bur gabo
# City not found. Skipping...
# Processing Record 502 of Set 10| manavalakurichi
# Processing Record 503 of Set 10| yarmouth
# Processing Record 504 of Set 10| borovoy
# Processing Record 505 of Set 10| tabuk
# Processing Record 506 of Set 10| badou
# Processing Record 507 of Set 10| ulundurpettai
# City not found. Skipping...
# Processing Record 508 of Set 10| baoma
# Processing Record 509 of Set 10| saschiz
# Processing Record 511 of Set 11| gazojak
# Processing Record 512 of Set 11| ferme-neuve
# Processing Record 513 of Set 11| caraquet
# Processing Record 514 of Set 11| mumbwa
# Processing Record 515 of Set 11| carauari
# Processing Record 516 of Set 11| kribi
# Processing Record 517 of Set 11| talcahuano
# Processing Record 518 of Set 11| jutai
# Processing Record 519 of Set 11| iquique
# Processing Record 520 of Set 11| thyolo
# Processing Record 521 of Set 11| lavumisa
# Processing Record 522 of Set 11| samoded
# Processing Record 523 of Set 11| gardabani
# Processing Record 524 of Set 11| abalak
# Processing Record 525 of Set 11| emba
# Processing Record 526 of Set 11| bolungarvik
# City not found. Skipping...
# Processing Record 527 of Set 11| melnikovo
# Processing Record 528 of Set 11| aksarka
# Processing Record 529 of Set 11| igunga
# Processing Record 530 of Set 11| gavirate
# Processing Record 531 of Set 11| ferrol
# Processing Record 532 of Set 11| sazonovo
# Processing Record 533 of Set 11| pozega
# Processing Record 534 of Set 11| berdyuzhye
# City not found. Skipping...
# Processing Record 535 of Set 11| villa oliva
# City not found. Skipping...
# Processing Record 536 of Set 11| nyzhni sirohozy
# Processing Record 537 of Set 11| great yarmouth
# Processing Record 538 of Set 11| bergerac
# Processing Record 539 of Set 11| katsiveli
# City not found. Skipping...
# Processing Record 540 of Set 11| conceicao do araguaia
# Processing Record 541 of Set 11| karauzyak
# City not found. Skipping...
# Processing Record 542 of Set 11| solovetskiy
# City not found. Skipping...
# Processing Record 543 of Set 11| new baltimore
# Processing Record 544 of Set 11| san ignacio
# Processing Record 545 of Set 11| port-gentil
# Processing Record 546 of Set 11| alta
# Processing Record 547 of Set 11| lakselv
# Processing Record 548 of Set 11| sao felix do xingu
# Processing Record 549 of Set 11| sao jose da coroa grande
# Processing Record 550 of Set 11| ramygala
# Processing Record 551 of Set 11| dothan
# Processing Record 552 of Set 11| harper
# Processing Record 553 of Set 11| kikwit
# Processing Record 554 of Set 11| kavaratti
# Processing Record 555 of Set 11| oneida
# Processing Record 556 of Set 11| ati
# Processing Record 557 of Set 11| bitlis
# Processing Record 558 of Set 11| kibala
# Processing Record 559 of Set 11| novyy urengoy
# Processing Record 560 of Set 11| ilorin
# Processing Record 562 of Set 12| sao miguel do tapuio
# Processing Record 563 of Set 12| buchanan
# Processing Record 564 of Set 12| kataysk
# Processing Record 565 of Set 12| parintins
# Processing Record 566 of Set 12| bonthe
# Processing Record 567 of Set 12| tyssedal
# Processing Record 568 of Set 12| raga
# Processing Record 569 of Set 12| usta muhammad
# Processing Record 570 of Set 12| umm durman
# City not found. Skipping...
# Processing Record 571 of Set 12| gao
# Processing Record 572 of Set 12| filingue
# Processing Record 573 of Set 12| iskateley
# Processing Record 574 of Set 12| alexandria
# Processing Record 575 of Set 12| maragogi
# Processing Record 576 of Set 12| coromandel
# Processing Record 577 of Set 12| cheuskiny
# City not found. Skipping...
# Processing Record 578 of Set 12| santhia
# Processing Record 579 of Set 12| romans-sur-isere
# Processing Record 580 of Set 12| leon
# Processing Record 581 of Set 12| abay
# Processing Record 582 of Set 12| matale
# Processing Record 583 of Set 12| amli
# Processing Record 584 of Set 12| peabiru
# Processing Record 585 of Set 12| rocha
# Processing Record 586 of Set 12| clarksville
# Processing Record 587 of Set 12| tiruvottiyur
# City not found. Skipping...
# Processing Record 588 of Set 12| sibenik
# Processing Record 589 of Set 12| letka
# Processing Record 590 of Set 12| blonduos
# City not found. Skipping...
# Processing Record 591 of Set 12| santa maria da vitoria
# Processing Record 592 of Set 12| pavelets
# Processing Record 593 of Set 12| ponta delgada
# Processing Record 594 of Set 12| hendijan
# City not found. Skipping...
# Processing Record 595 of Set 12| sarakhs
# Processing Record 596 of Set 12| kaspiyskiy
# Processing Record 597 of Set 12| masyaf
# Processing Record 598 of Set 12| maniitsoq
# Processing Record 599 of Set 12| wattegama
# Processing Record 600 of Set 12| dobroye
# Processing Record 601 of Set 12| araci
# Processing Record 602 of Set 12| albany
# Processing Record 603 of Set 12| adet
# Processing Record 604 of Set 12| lamu
# Processing Record 605 of Set 12| la asuncion
# Processing Record 606 of Set 12| riom
# Processing Record 607 of Set 12| bengkulu
# Processing Record 608 of Set 12| vacaria
# Processing Record 609 of Set 12| bennington
# Processing Record 610 of Set 12| villa carlos paz
# Processing Record 611 of Set 12| barreirinhas
# Processing Record 613 of Set 13| porto novo
# Processing Record 614 of Set 13| teeli
# Processing Record 615 of Set 13| tacuarembo
# Processing Record 616 of Set 13| itarema
# Processing Record 617 of Set 13| knysna
# Processing Record 618 of Set 13| kudahuvadhoo
# Processing Record 619 of Set 13| farim
# Processing Record 620 of Set 13| antofagasta
# Processing Record 621 of Set 13| jemnice
# Processing Record 622 of Set 13| ramonville-saint-agne
# Processing Record 623 of Set 13| cockburn town
# Processing Record 624 of Set 13| oktyabrskiy
# Processing Record 625 of Set 13| la palma
# Processing Record 626 of Set 13| sorvag
# City not found. Skipping...
# Processing Record 627 of Set 13| abnub
# Processing Record 628 of Set 13| dobele
# Processing Record 629 of Set 13| bhagalpur
# Processing Record 630 of Set 13| santa cruz de tenerife
# Processing Record 631 of Set 13| lagunas
# Processing Record 632 of Set 13| suraabad
# Processing Record 633 of Set 13| khamgaon
# Processing Record 634 of Set 13| yarada
# Processing Record 635 of Set 13| tondi
# Processing Record 636 of Set 13| eydhafushi
# Processing Record 637 of Set 13| eravur
# Processing Record 638 of Set 13| caete
# Processing Record 639 of Set 13| mjolby
# Processing Record 640 of Set 13| nara
# Processing Record 641 of Set 13| lar
# Processing Record 642 of Set 13| claudio
# Processing Record 643 of Set 13| sladkovo
# Processing Record 644 of Set 13| isparta
# Processing Record 645 of Set 13| ardalstangen
# Processing Record 646 of Set 13| zanjan
# Processing Record 647 of Set 13| kjopsvik
# Processing Record 648 of Set 13| minab
# Processing Record 649 of Set 13| copiapo
# Processing Record 650 of Set 13| saint pete beach
# Processing Record 651 of Set 13| subacius
# City not found. Skipping...
# Processing Record 652 of Set 13| fatsa
# Processing Record 653 of Set 13| porto belo
# Processing Record 654 of Set 13| fowa
# Processing Record 655 of Set 13| arrecife
# Processing Record 656 of Set 13| ndioum
# Processing Record 657 of Set 13| sayville
# Processing Record 658 of Set 13| lima
# Processing Record 659 of Set 13| elizabeth city
# Processing Record 660 of Set 13| tawkar
# City not found. Skipping...
# Processing Record 661 of Set 13| gouyave
# Processing Record 662 of Set 13| calabozo
# Processing Record 664 of Set 14| kisesa
# Processing Record 665 of Set 14| kaabong
# Processing Record 666 of Set 14| marawi
# Processing Record 667 of Set 14| marsaxlokk
# Processing Record 668 of Set 14| aasiaat
# Processing Record 669 of Set 14| anavissos
# City not found. Skipping...
# Processing Record 670 of Set 14| carutapera
# Processing Record 671 of Set 14| santa isabel do rio negro
# Processing Record 672 of Set 14| kabinda
# Processing Record 673 of Set 14| kondinskoye
# Processing Record 674 of Set 14| belem
# Processing Record 675 of Set 14| panjab
# Processing Record 676 of Set 14| lezajsk
# Processing Record 677 of Set 14| sambava
# Processing Record 678 of Set 14| tuggurt
# City not found. Skipping...
# Processing Record 679 of Set 14| bajos de haina
# Processing Record 680 of Set 14| sparbu
# Processing Record 681 of Set 14| narasannapeta
# Processing Record 682 of Set 14| aquiraz
# Processing Record 683 of Set 14| thaba nchu
# Processing Record 684 of Set 14| znamenskoye
# Processing Record 685 of Set 14| syamzha
# Processing Record 686 of Set 14| peterhead
# Processing Record 687 of Set 14| mirador
# Processing Record 688 of Set 14| sendafa
# Processing Record 689 of Set 14| komsomolskiy
# Processing Record 690 of Set 14| yirol
# City not found. Skipping...
# Processing Record 691 of Set 14| karabulak
# Processing Record 692 of Set 14| warah
# Processing Record 693 of Set 14| bressuire
# Processing Record 694 of Set 14| nauta
# Processing Record 695 of Set 14| sisimiut
# Processing Record 696 of Set 14| kalabo
# Processing Record 697 of Set 14| oranjemund
# Processing Record 698 of Set 14| susangerd
# Processing Record 699 of Set 14| misratah
# Processing Record 700 of Set 14| dubrovnik
# Processing Record 701 of Set 14| kadoma
# Processing Record 702 of Set 14| constitucion
# Processing Record 703 of Set 14| balkhash
# Processing Record 704 of Set 14| moroto
# Processing Record 705 of Set 14| mgandu
# Processing Record 706 of Set 14| kangaatsiaq
# Processing Record 707 of Set 14| karaton
# Processing Record 708 of Set 14| karpathos
# Processing Record 709 of Set 14| zuenoula
# Processing Record 710 of Set 14| norrtalje
# Processing Record 711 of Set 14| itatskiy
# Processing Record 712 of Set 14| yokadouma
# Processing Record 713 of Set 14| brasileia
# Processing Record 715 of Set 15| strezhevoy
# Processing Record 716 of Set 15| shebekino
# Processing Record 717 of Set 15| benjamin aceval
# Processing Record 718 of Set 15| malindi
# Processing Record 719 of Set 15| boyuibe
# Processing Record 720 of Set 15| manali
# Processing Record 721 of Set 15| moose factory
# Processing Record 722 of Set 15| bereda
# Processing Record 723 of Set 15| kidal
# Processing Record 724 of Set 15| voznesenye
# Processing Record 725 of Set 15| yaounde
# Processing Record 726 of Set 15| havre-saint-pierre
# Processing Record 727 of Set 15| ambikapur
# Processing Record 728 of Set 15| baglung
# Processing Record 729 of Set 15| oleksandrivka
# Processing Record 730 of Set 15| dabat
# Processing Record 731 of Set 15| karasburg
# Processing Record 732 of Set 15| biabou
# Processing Record 733 of Set 15| shache
# Processing Record 734 of Set 15| ferkessedougou
# Processing Record 735 of Set 15| valparaiso
# Processing Record 736 of Set 15| caorle
# Processing Record 737 of Set 15| saint-louis
# Processing Record 738 of Set 15| salta
# Processing Record 739 of Set 15| eyl
# Processing Record 740 of Set 15| mmathubudukwane
# Processing Record 741 of Set 15| tolyatti
# Processing Record 742 of Set 15| karamay
# City not found. Skipping...
# Processing Record 743 of Set 15| kabwe
# Processing Record 744 of Set 15| sao paulo de olivenca
# Processing Record 745 of Set 15| kuusamo
# Processing Record 746 of Set 15| cordoba
# Processing Record 747 of Set 15| muscat
# Processing Record 748 of Set 15| sabla
# Processing Record 749 of Set 15| guaruja
# Processing Record 750 of Set 15| nizwa
# Processing Record 751 of Set 15| sehwan
# Processing Record 752 of Set 15| sao gabriel da cachoeira
# Processing Record 753 of Set 15| santa maria
# Processing Record 754 of Set 15| omaruru
# Processing Record 755 of Set 15| manono
# Processing Record 756 of Set 15| vagay
# Processing Record 757 of Set 15| mecca
# Processing Record 758 of Set 15| kjollefjord
# Processing Record 759 of Set 15| sanchor
# Processing Record 760 of Set 15| bhatkal
# Processing Record 761 of Set 15| la pena
# Processing Record 762 of Set 15| jacareacanga
# Processing Record 763 of Set 15| chicama
# Processing Record 764 of Set 15| ercis
# Processing Record 766 of Set 16| palpa
# Processing Record 767 of Set 16| fairhaven
# Processing Record 768 of Set 16| lokot
# Processing Record 769 of Set 16| gat
# Processing Record 770 of Set 16| praia
# Processing Record 771 of Set 16| kitui
# Processing Record 772 of Set 16| hustopece
# Processing Record 773 of Set 16| tiznit
# Processing Record 774 of Set 16| santona
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 706

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0           Hualmay -11.0964 -77.6139     62.13        84          43
# 1           Ushuaia -54.8000 -68.3000     44.26        61          40
# 2            Matara   5.9485  80.5353     81.07        81          84
# 3        Port Blair  11.6667  92.7500     82.35        79          69
# 4            Rudsar  37.1376  50.2880     67.98        71           0
# 5  Praia Da Vitoria  38.7333 -27.0667     68.25        77          20
# 6             Bayji  34.9311  43.4870     77.58        38           0
# 7    Saint-Philippe -21.3585  55.7679     71.15        80          38
# 8       Port Alfred -33.5906  26.8910     60.66        82         100
# 9       Kesova Gora  57.5836  37.2922     40.82        98          82
#
#    Wind Speed Country                 Date      Current Description
# 0        7.05      PE  2021-09-24 02:21:10         scattered clouds
# 1       17.27      AR  2021-09-24 02:21:10  light intensity drizzle
# 2       10.27      LK  2021-09-24 02:21:10            broken clouds
# 3       11.95      IN  2021-09-24 02:21:11            broken clouds
# 4        3.40      IR  2021-09-24 02:21:11                clear sky
# 5        9.73      PT  2021-09-24 02:21:11               few clouds
# 6        6.69      IQ  2021-09-24 02:21:11                clear sky
# 7       10.60      RE  2021-09-24 02:21:12         scattered clouds
# 8       12.97      ZA  2021-09-24 02:21:12          overcast clouds
# 9        6.60      RU  2021-09-24 02:21:12            broken clouds

# %%
# Reorder the column order
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head()
city_data_df.count()
# Out:
# City                   706
# Country                706
# Lat                    706
# Lng                    706
# Max Temp               706
# Humidity               706
# Cloudiness             706
# Wind Speed             706
# Current Description    706
# dtype: int64

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
