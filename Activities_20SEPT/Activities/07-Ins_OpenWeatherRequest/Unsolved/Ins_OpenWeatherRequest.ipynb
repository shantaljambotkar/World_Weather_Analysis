# %%
# Dependencies
import json
import requests
from config import api_key

# %%
# Save config information

url = 'http://api.openweathermap.org/data/2.5/forecast?q=London&appid=d82315617a31ae0da2844e056aa6eee6'

data_from_api = requests.get(url).json()

data_from_api


# url = "http://api.openweathermap.org/data/2.5/weather?"
# city = "London"

# # Build query URL
# query_url = url + "api-key=" + api_key + "&q=" + city

# print(query_url)
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1632193200,
#    'main': {'temp': 286.87,
#     'feels_like': 286.57,
#     'temp_min': 286.54,
#     'temp_max': 286.87,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1025,
#     'humidity': 87,
#     'temp_kf': 0.33},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 64},
#    'wind': {'speed': 1.16, 'deg': 354, 'gust': 1.47},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-09-21 03:00:00'},
#   {'dt': 1632204000,
#    'main': {'temp': 286.3,
#     'feels_like': 285.97,
#     'temp_min': 285.93,
#     'temp_max': 286.3,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1026,
#     'humidity': 88,
#     'temp_kf': 0.37},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 68},
#    'wind': {'speed': 0.61, 'deg': 325, 'gust': 0.67},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-09-21 06:00:00'},
#   {'dt': 1632214800,
#    'main': {'temp': 289.11,
#     'feels_like': 288.51,
#     'temp_min': 289.11,
#     'temp_max': 289.11,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 1028,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 72},
#    'wind': {'speed': 1.5, 'deg': 332, 'gust': 2.13},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-09-21 09:00:00'},
#   {'dt': 1632225600,
#    'main': {'temp': 292.49,
#     'feels_like': 291.79,
#     'temp_min': 292.49,
#     'temp_max': 292.49,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'grnd_level': 1027,
#     'humidity': 50,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 86},
#    'wind': {'speed': 0.68, 'deg': 328, 'gust': 0.95},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-09-21 12:00:00'},
#   {'dt': 1632236400,
#    'main': {'temp': 293.44,
#     'feels_like': 292.83,
#     'temp_min': 293.44,
#     'temp_max': 293.44,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1026,
#     'humidity': 50,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.39, 'deg': 299, 'gust': 1.94},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-09-21 15:00:00'},
#   {'dt': 1632247200,
#    'main': {'temp': 291.76,
#     'feels_like': 291.22,
#     'temp_min': 291.76,
#     'temp_max': 291.76,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1026,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.32, 'deg': 322, 'gust': 1.88},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-09-21 18:00:00'},
#   {'dt': 1632258000,
#    'main': {'temp': 290.16,
#     'feels_like': 289.61,
#     'temp_min': 290.16,
#     'temp_max': 290.16,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'grnd_level': 1027,
#     'humidity': 65,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 0.93, 'deg': 288, 'gust': 0.94},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-09-21 21:00:00'},
#   {'dt': 1632268800,
#    'main': {'temp': 288.49,
#     'feels_like': 287.96,
#     'temp_min': 288.49,
#     'temp_max': 288.49,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1026,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 81},
#    'wind': {'speed': 1.72, 'deg': 236, 'gust': 2.7},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-09-22 00:00:00'},
#   {'dt': 1632279600,
#    'main': {'temp': 287.25,
#     'feels_like': 286.75,
#     'temp_min': 287.25,
#     'temp_max': 287.25,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1025,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 90},
#    'wind': {'speed': 1.76, 'deg': 233, 'gust': 3.95},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-09-22 03:00:00'},
#   {'dt': 1632290400,
#    'main': {'temp': 286.4,
#     'feels_like': 285.92,
#     'temp_min': 286.4,
#     'temp_max': 286.4,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1025,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 88},
#    'wind': {'speed': 1.81, 'deg': 224, 'gust': 4.18},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-09-22 06:00:00'},
#   {'dt': 1632301200,
#    'main': {'temp': 290.18,
#     'feels_like': 289.58,
#     'temp_min': 290.18,
#     'temp_max': 290.18,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1025,
#     'humidity': 63,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 45},
#    'wind': {'speed': 2.72, 'deg': 240, 'gust': 4.38},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-09-22 09:00:00'},
#   {'dt': 1632312000,
#    'main': {'temp': 294.24,
#     'feels_like': 293.58,
#     'temp_min': 294.24,
#     'temp_max': 294.24,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1023,
#     'humidity': 45,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 54},
#    'wind': {'speed': 3.02, 'deg': 255, 'gust': 4.11},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-09-22 12:00:00'},
#   {'dt': 1632322800,
#    'main': {'temp': 295.71,
#     'feels_like': 295.12,
#     'temp_min': 295.71,
#     'temp_max': 295.71,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'grnd_level': 1021,
#     'humidity': 42,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 3.62, 'deg': 253, 'gust': 4.81},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-09-22 15:00:00'},
#   {'dt': 1632333600,
#    'main': {'temp': 292.94,
#     'feels_like': 292.44,
#     'temp_min': 292.94,
#     'temp_max': 292.94,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'grnd_level': 1021,
#     'humidity': 56,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 5},
#    'wind': {'speed': 2.77, 'deg': 250, 'gust': 6.39},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-09-22 18:00:00'},
#   {'dt': 1632344400,
#    'main': {'temp': 289.94,
#     'feels_like': 289.58,
#     'temp_min': 289.94,
#     'temp_max': 289.94,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'grnd_level': 1021,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 3.33, 'deg': 257, 'gust': 7.72},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-09-22 21:00:00'},
#   {'dt': 1632355200,
#    'main': {'temp': 287.53,
#     'feels_like': 287.11,
#     'temp_min': 287.53,
#     'temp_max': 287.53,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1019,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 12},
#    'wind': {'speed': 2.96, 'deg': 257, 'gust': 6.32},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-09-23 00:00:00'},
#   {'dt': 1632366000,
#    'main': {'temp': 286.31,
#     'feels_like': 285.82,
#     'temp_min': 286.31,
#     'temp_max': 286.31,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1019,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 51},
#    'wind': {'speed': 2.61, 'deg': 251, 'gust': 6.32},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-09-23 03:00:00'},
#   {'dt': 1632376800,
#    'main': {'temp': 286,
#     'feels_like': 285.51,
#     'temp_min': 286,
#     'temp_max': 286,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1018,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 75},
#    'wind': {'speed': 2.91, 'deg': 240, 'gust': 8.28},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-09-23 06:00:00'},
#   {'dt': 1632387600,
#    'main': {'temp': 290.17,
#     'feels_like': 289.83,
#     'temp_min': 290.17,
#     'temp_max': 290.17,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1017,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 70},
#    'wind': {'speed': 4.04, 'deg': 261, 'gust': 8.12},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-09-23 09:00:00'},
#   {'dt': 1632398400,
#    'main': {'temp': 293.89,
#     'feels_like': 293.64,
#     'temp_min': 293.89,
#     'temp_max': 293.89,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1016,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 85},
#    'wind': {'speed': 4.95, 'deg': 285, 'gust': 7.83},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-09-23 12:00:00'},
#   {'dt': 1632409200,
#    'main': {'temp': 295.21,
#     'feels_like': 294.72,
#     'temp_min': 295.21,
#     'temp_max': 295.21,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1014,
#     'humidity': 48,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 4.36, 'deg': 288, 'gust': 6.01},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-09-23 15:00:00'},
#   {'dt': 1632420000,
#    'main': {'temp': 292.84,
#     'feels_like': 292.27,
#     'temp_min': 292.84,
#     'temp_max': 292.84,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1015,
#     'humidity': 54,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 57},
#    'wind': {'speed': 2.71, 'deg': 298, 'gust': 6.55},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-09-23 18:00:00'},
#   {'dt': 1632430800,
#    'main': {'temp': 290.64,
#     'feels_like': 290.06,
#     'temp_min': 290.64,
#     'temp_max': 290.64,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1015,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 11},
#    'wind': {'speed': 2.11, 'deg': 268, 'gust': 5.56},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-09-23 21:00:00'},
#   {'dt': 1632441600,
#    'main': {'temp': 289.02,
#     'feels_like': 288.49,
#     'temp_min': 289.02,
#     'temp_max': 289.02,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1014,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 10},
#    'wind': {'speed': 2.06, 'deg': 255, 'gust': 4.67},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-09-24 00:00:00'},
#   {'dt': 1632452400,
#    'main': {'temp': 287.92,
#     'feels_like': 287.33,
#     'temp_min': 287.92,
#     'temp_max': 287.92,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1013,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.24, 'deg': 242, 'gust': 5.77},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-09-24 03:00:00'},
#   {'dt': 1632463200,
#    'main': {'temp': 287.03,
#     'feels_like': 286.54,
#     'temp_min': 287.03,
#     'temp_max': 287.03,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1012,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.68, 'deg': 233, 'gust': 7.08},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-09-24 06:00:00'},
#   {'dt': 1632474000,
#    'main': {'temp': 290.74,
#     'feels_like': 289.94,
#     'temp_min': 290.74,
#     'temp_max': 290.74,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1012,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.59, 'deg': 254, 'gust': 6.11},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-09-24 09:00:00'},
#   {'dt': 1632484800,
#    'main': {'temp': 295.54,
#     'feels_like': 295.27,
#     'temp_min': 295.54,
#     'temp_max': 295.54,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1011,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.56, 'deg': 249, 'gust': 6.87},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-09-24 12:00:00'},
#   {'dt': 1632495600,
#    'main': {'temp': 296.82,
#     'feels_like': 296.68,
#     'temp_min': 296.82,
#     'temp_max': 296.82,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1009,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 10},
#    'wind': {'speed': 5.73, 'deg': 266, 'gust': 8.31},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-09-24 15:00:00'},
#   {'dt': 1632506400,
#    'main': {'temp': 293.62,
#     'feels_like': 293.45,
#     'temp_min': 293.62,
#     'temp_max': 293.62,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1010,
#     'humidity': 66,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 4.32, 'deg': 264, 'gust': 8.91},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-09-24 18:00:00'},
#   {'dt': 1632517200,
#    'main': {'temp': 291.27,
#     'feels_like': 291.2,
#     'temp_min': 291.27,
#     'temp_max': 291.27,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1011,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 9},
#    'wind': {'speed': 3.29, 'deg': 251, 'gust': 8.12},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-09-24 21:00:00'},
#   {'dt': 1632528000,
#    'main': {'temp': 289.84,
#     'feels_like': 289.81,
#     'temp_min': 289.84,
#     'temp_max': 289.84,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1011,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 12},
#    'wind': {'speed': 2.77, 'deg': 248, 'gust': 7.04},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-09-25 00:00:00'},
#   {'dt': 1632538800,
#    'main': {'temp': 290.17,
#     'feels_like': 290.09,
#     'temp_min': 290.17,
#     'temp_max': 290.17,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1011,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 87},
#    'wind': {'speed': 2.53, 'deg': 269, 'gust': 6.98},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-09-25 03:00:00'},
#   {'dt': 1632549600,
#    'main': {'temp': 290.17,
#     'feels_like': 290.07,
#     'temp_min': 290.17,
#     'temp_max': 290.17,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1011,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 1.98, 'deg': 253, 'gust': 6.3},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-09-25 06:00:00'},
#   {'dt': 1632560400,
#    'main': {'temp': 292.12,
#     'feels_like': 291.72,
#     'temp_min': 292.12,
#     'temp_max': 292.12,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1012,
#     'humidity': 63,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.83, 'deg': 273, 'gust': 4.81},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-09-25 09:00:00'},
#   {'dt': 1632571200,
#    'main': {'temp': 295.07,
#     'feels_like': 294.68,
#     'temp_min': 295.07,
#     'temp_max': 295.07,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1011,
#     'humidity': 52,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 83},
#    'wind': {'speed': 2.56, 'deg': 279, 'gust': 3.57},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-09-25 12:00:00'},
#   {'dt': 1632582000,
#    'main': {'temp': 295.05,
#     'feels_like': 294.71,
#     'temp_min': 295.05,
#     'temp_max': 295.05,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1011,
#     'humidity': 54,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 2.16, 'deg': 271, 'gust': 3.19},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-09-25 15:00:00'},
#   {'dt': 1632592800,
#    'main': {'temp': 293.53,
#     'feels_like': 293.32,
#     'temp_min': 293.53,
#     'temp_max': 293.53,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1011,
#     'humidity': 65,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 2.63, 'deg': 222, 'gust': 4.52},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-09-25 18:00:00'},
#   {'dt': 1632603600,
#    'main': {'temp': 291.73,
#     'feels_like': 291.58,
#     'temp_min': 291.73,
#     'temp_max': 291.73,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1011,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.85, 'deg': 218, 'gust': 5.37},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2021-09-25 21:00:00'},
#   {'dt': 1632614400,
#    'main': {'temp': 289.9,
#     'feels_like': 289.75,
#     'temp_min': 289.9,
#     'temp_max': 289.9,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1011,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 81},
#    'wind': {'speed': 1.81, 'deg': 221, 'gust': 3.58},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2021-09-26 00:00:00'}],
#  'city': {'id': 2643743,
#   'name': 'London',
#   'coord': {'lat': 51.5085, 'lon': -0.1257},
#   'country': 'GB',
#   'population': 1000000,
#   'timezone': 3600,
#   'sunrise': 1632203106,
#   'sunset': 1632247325}}

# %%
# Get weather data

# Request articles
articles = requests.get(query_url).json()

# Get the temperature from the response
